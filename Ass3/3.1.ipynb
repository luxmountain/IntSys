# %%
import tensorflow as tf

tf.compat.v1.disable_eager_execution()

h = tf.constant("Hello")
w = tf.constant(" World!")
hw = h + w

with tf.compat.v1.Session() as sess:
    ans = sess.run(hw)
    print(ans.decode())
# Out:
# Hello World!

# %%
Ta Cao Son

# %%
import tensorflow.compat.v1 as tf 
x = tf.constant(5,tf.float32) 
y = tf.constant([5], tf.float32) 
z = tf.constant([5,3,4], tf.float32) 
t = tf.constant([[5,3,4,6],[2,3,4,7]], tf.float32) 
u = tf.constant([[[5,3,4,6],[2,3,4,0]]], tf.float32) 
v = tf.constant([[[5,3,4,6],[2,3,4,0]], 
                 [[5,3,4,6],[2,3,4,0]], 
                 [[5,3,4,6],[2,3,4,0]] 
                ], tf.float32) 
print(v)
# Out:
# Tensor("Const_13:0", shape=(3, 2, 4), dtype=float32)
