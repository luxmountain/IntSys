# %%
import numpy as np

# Create arrays
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# Vectorized operations
print(a + b)      # [5 7 9]
print(a * b)      # [ 4 10 18]

# Statistics
print(np.mean(a)) # 2.0
